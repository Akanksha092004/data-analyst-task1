# %% [markdown]
# <a href="https://colab.research.google.com/github/Akanksha092004/data-analyst-task1/blob/main/task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datetime import datetime
import numpy as np
import pandas as pd

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("/content/sample_data/intership/netflix_dataset.csv")

# %% [markdown]
# before cleaning

# %%
print("Before Cleaning:")
print(df.shape)
print(df.isnull().sum())
# Out:
# Before Cleaning:
# (300, 7)
# title            0
# type             0
# country         59
# date_added      68
# release_year    57
# rating          57
# genre           60
# dtype: int64

# %% [markdown]
# 1. Remove missing values

# %%
df = df.dropna()

# %% [markdown]
#  2. Remove duplicates

# %%
df = df.drop_duplicates()

# %% [markdown]
# 3. Clean text columns

# %%
for col in df.select_dtypes(include='object').columns:
    df[col] = df[col].str.lower().str.strip()

# %% [markdown]
# 4. Rename columns

# %%
df.columns = df.columns.str.lower().str.replace(" ", "_")

# %%
df.head(5)
# Out:
#        title     type country     date_added  release_year rating     genre
# 0   series e    movie     usa     2021-02-15        2019.0      r    action
# 5    movie b  tv show      uk     2021-02-15        2021.0      r    comedy
# 12    show c    movie      uk  15 march 2022        2019.0     pg    action
# 16    film d  tv show   india     2021-02-15        2021.0      r  thriller
# 17    show c    movie   india  15 march 2022        2020.0     pg     drama

# %% [markdown]
# 5. Convert date column

# %%
df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')

# %%
df.head(5)
# Out:
#        title     type country date_added  release_year rating     genre
# 0   series e    movie     usa 2021-02-15        2019.0      r    action
# 5    movie b  tv show      uk 2021-02-15        2021.0      r    comedy
# 12    show c    movie      uk        NaT        2019.0     pg    action
# 16    film d  tv show   india 2021-02-15        2021.0      r  thriller
# 17    show c    movie   india        NaT        2020.0     pg     drama

# %%
print(df.dtypes)
# Out:
# title                   object
# type                    object
# country                 object
# date_added      datetime64[ns]
# release_year           float64
# rating                  object
# genre                   object
# dtype: object

# %%
df['release_year'] = df['release_year'].astype(int)

# %% [markdown]
#  After cleaning

# %%
print("\nAfter Cleaning:")
print(df.shape)
print(df.isnull().sum())
# Out:
# After Cleaning:
# (100, 7)
# title            0
# type             0
# country          0
# date_added      73
# release_year     0
# rating           0
# genre            0
# dtype: int64

# %%
df.to_csv("cleaned_netflix_dataset.csv", index=False)

# %%
print(df)
# Out:
#         title     type country date_added  release_year rating     genre
# 0    series e    movie     usa 2021-02-15          2019      r    action
# 5     movie b  tv show      uk 2021-02-15          2021      r    comedy
# 12     show c    movie      uk        NaT          2019     pg    action
# 16     film d  tv show   india 2021-02-15          2021      r  thriller
# 17     show c    movie   india        NaT          2020     pg     drama
# ..        ...      ...     ...        ...           ...    ...       ...
# 292  series e  tv show      uk        NaT          2019      r     drama
# 293   movie a  tv show   india 2021-02-15          2020  tv-ma     drama
# 295  series e  tv show      uk        NaT          2019      r    comedy
# 296    film d  tv show      uk 2021-02-15          2021     pg    action
# 298    film d    movie   india 2021-02-15          2021      r    comedy
#
# [100 rows x 7 columns]
